# %%
#THERESA BRONS, MARCH 2021
import pandas as pd
import datetime
from datetime import date, timedelta
from collections import defaultdict
from dateutil import relativedelta
import os
import glob
from authorize_creds import authorize_creds

sc_site = SITE_URL
num_days = 481                    # Number of Days, Months to Extract

creds = 'client_secret_desktop.json'   
output = 'gsc_data'
project_name = PROJECT_NAME

search_types = ['web','image','video']

#storage folder is where you'll get dates for the data you already are storing.  DO NOT INCLUDE SEARCH TYPE!
#i keep all the search type data in the same folder
STORAGE_FOLDER = '' #IF YOU CURRENTLY STORE STUFF IN CSV, YOU CAN READ DATES YOU'VE ALREADY GATHERED DATA FOR
#output folder will usually be same as storage folder
OUTPUT_FOLDER = STORAGE_FOLDER


        

# Create Function to execute your API Request
def execute_request(service, property_uri, request):
    return service.searchanalytics().query(siteUrl=property_uri, body=request).execute()
 
# Create function to write to CSV
def write_to_csv(data,filename):
    if not os.path.isfile(filename):
        data.to_csv(filename, index=False)
    else: # else it exists so append without writing the header
        data.to_csv(filename, mode='a', header=False, index=False)
        
def get_files(path):
    #This returns a complete list of csv files within the given subdirectory.  
    #It prepends the subdirectory name to each filename.
    cwd = os.getcwd()
    os.chdir(path)
    
    files=[]
    for filename in glob.glob('*.csv'):
        files.append(os.getcwd() + '/' + filename)
    os.chdir(cwd)
    return files
        
# Read CSV if it exists to find dates that have already been processed.
def get_dates_from_csv(path):
    
    #grab list of file names, full path
    dates = set( [file[-14:-4] for file in get_files(path)] )
    
    return dates

 
    
# Create function to extract all the data
def granular_extract(creds, num_days, search_type, storage_folder = STORAGE_FOLDER, output_folder = OUTPUT_FOLDER):
    full_path = storage_folder + '/' + search_type + '/' 
    
    current_dates = get_dates_from_csv(full_path)

    webmasters_service = authorize_creds()
 
    # Set up Dates
    end_date = datetime.date.today() - relativedelta.relativedelta(days=3)
    start_date = end_date - relativedelta.relativedelta(days=num_days)
   
    
    delta = datetime.timedelta(days=1) # This will let us loop one day at the time
    
 

    while start_date <= end_date:
        iteration_num=0

        scDict = defaultdict(list)

        if current_dates is not None and current_dates.issuperset([datetime.datetime.strftime(start_date,'%Y-%m-%d')]):
            print('Existing Date: %s' % start_date)
            start_date += delta     
        else:
            print('Start date at beginning: %s' % start_date)
     
            maxRows = 25000 # Maximum 25K per call 
            numRows = 0     # Start at Row Zero
            status = ''     # Initialize status of extraction
 
            while (status != 'Finished') : # Test with i < 10 just to see how long the task will take to process.
                request = {
                    'startDate': datetime.datetime.strftime(start_date,'%Y-%m-%d'),
                    'endDate': datetime.datetime.strftime(start_date,'%Y-%m-%d'),
                    'dimensions': ['date','page','query']#,'device','country'],
                    'rowLimit': maxRows,
                    'searchType': search_type,
                    'startRow': numRows
                }

                response = execute_request(webmasters_service, sc_site , request)
                
                try:
                #Process the response
                
                # ok scDict is having shit appended to it....I think the df is being redefined each loop
                # but the scDict is still growing so it's not noticed.
                    for row in response['rows']:
                        scDict['date'].append(row['keys'][0] or 0) 
                        scDict['page'].append(row['keys'][1] or 0)
                        scDict['query'].append(row['keys'][2] or 0)
                        scDict['clicks'].append(row['clicks'] or 0)
                        scDict['ctr'].append(row['ctr'] or 0)
                        scDict['impressions'].append(row['impressions'] or 0)
                        scDict['position'].append(row['position'] or 0)
                        #scDict['device'].append(row['keys'][3] or 0)
                        #scDict['country'].append(row['keys'][4] or 0)                        
                    
                except:
                    print('error occurred at %i' % numRows)
 
                #Add response to dataframe 
                df = pd.DataFrame(data = scDict)
                df['clicks'] = df['clicks'].astype('int')
                df['ctr'] = df['ctr']*100
                df['impressions'] = df['impressions'].astype('int')
                df['position'] = df['position'].round(2)
                print('writing file: ' + full_path + '_' + str(start_date) + '.csv')
                try:
                    print('writing to csv')
                    
                    write_to_csv(df, full_path  + 'GSC_'+search_type +'_'+ str(iteration_num) + '_' + str(start_date) + '.csv')
                    iteration_num+=1
                except Exception as e:
                    print(full_path + 'GSC_' + search_type +'_' + str(iteration_num) + '_' + str(start_date) + '.csv')
                    print(e)
                    return               
                
                print('Numrows at the start of loop: %i' % numRows)
                try: 
                    numRows = numRows + len(response['rows'])
                except:
                    status = 'Finished'
                print('Numrows at the end of loop: %i' % numRows)
                if numRows % maxRows != 0:
                    status = 'Finished'
         
            start_date += delta  
            print('Start date at end: %s' % start_date) 
            #write_to_csv(df,full_path)
    return
# Out:
# Existing Date: 2019-11-25
# Existing Date: 2019-11-26
# Existing Date: 2019-11-27
# Existing Date: 2019-11-28
# Existing Date: 2019-11-29
# Existing Date: 2019-11-30
# Existing Date: 2019-12-01
# Existing Date: 2019-12-02
# Existing Date: 2019-12-03
# Existing Date: 2019-12-04
# Existing Date: 2019-12-05
# Existing Date: 2019-12-06
# Existing Date: 2019-12-07
# Existing Date: 2019-12-08
# Existing Date: 2019-12-09
# Existing Date: 2019-12-10
# Existing Date: 2019-12-11
# Existing Date: 2019-12-12
# Existing Date: 2019-12-13
# Existing Date: 2019-12-14
# Existing Date: 2019-12-15
# Existing Date: 2019-12-16
# Existing Date: 2019-12-17
# Existing Date: 2019-12-18
# Existing Date: 2019-12-19
# Existing Date: 2019-12-20
# Existing Date: 2019-12-21
# Existing Date: 2019-12-22
# Existing Date: 2019-12-23
# Existing Date: 2019-12-24
# Existing Date: 2019-12-25
# Existing Date: 2019-12-26
# Existing Date: 2019-12-27
# Existing Date: 2019-12-28
# Existing Date: 2019-12-29
# Existing Date: 2019-12-30
# Existing Date: 2019-12-31
# Existing Date: 2020-01-01
# Existing Date: 2020-01-02
# Existing Date: 2020-01-03
# Existing Date: 2020-01-04
# Existing Date: 2020-01-05
# Existing Date: 2020-01-06
# Existing Date: 2020-01-07
# Existing Date: 2020-01-08
# Existing Date: 2020-01-09
# Existing Date: 2020-01-10
# Existing Date: 2020-01-11
# Existing Date: 2020-01-12
# Existing Date: 2020-01-13
# Existing Date: 2020-01-14
# Existing Date: 2020-01-15
# Existing Date: 2020-01-16
# Existing Date: 2020-01-17
# Existing Date: 2020-01-18
# Existing Date: 2020-01-19
# Existing Date: 2020-01-20
# Existing Date: 2020-01-21
# Existing Date: 2020-01-22
# Existing Date: 2020-01-23
# Existing Date: 2020-01-24
# Existing Date: 2020-01-25
# Existing Date: 2020-01-26
# Existing Date: 2020-01-27
# Existing Date: 2020-01-28
# Existing Date: 2020-01-29
# Existing Date: 2020-01-30
# Existing Date: 2020-01-31
# Existing Date: 2020-02-01
# Existing Date: 2020-02-02
# Existing Date: 2020-02-03
# Existing Date: 2020-02-04
# Existing Date: 2020-02-05
# Existing Date: 2020-02-06
# Existing Date: 2020-02-07
# Existing Date: 2020-02-08
# Existing Date: 2020-02-09
# Existing Date: 2020-02-10
# Existing Date: 2020-02-11
# Existing Date: 2020-02-12
# Existing Date: 2020-02-13
# Existing Date: 2020-02-14
# Existing Date: 2020-02-15
# Existing Date: 2020-02-16
# Existing Date: 2020-02-17
# Existing Date: 2020-02-18
# Existing Date: 2020-02-19
# Existing Date: 2020-02-20
# Existing Date: 2020-02-21
# Existing Date: 2020-02-22
# Existing Date: 2020-02-23
# Existing Date: 2020-02-24
# Existing Date: 2020-02-25
# Existing Date: 2020-02-26
# Existing Date: 2020-02-27
# Existing Date: 2020-02-28
# Existing Date: 2020-02-29
# Existing Date: 2020-03-01
# Existing Date: 2020-03-02
# Existing Date: 2020-03-03
# Existing Date: 2020-03-04
# Existing Date: 2020-03-05
# Existing Date: 2020-03-06
# Existing Date: 2020-03-07
# Existing Date: 2020-03-08
# Existing Date: 2020-03-09
# Existing Date: 2020-03-10
# Existing Date: 2020-03-11
# Existing Date: 2020-03-12
# Existing Date: 2020-03-13
# Existing Date: 2020-03-14
# Existing Date: 2020-03-15
# Existing Date: 2020-03-16
# Existing Date: 2020-03-17
# Existing Date: 2020-03-18
# Existing Date: 2020-03-19
# Existing Date: 2020-03-20
# Existing Date: 2020-03-21
# Existing Date: 2020-03-22
# Existing Date: 2020-03-23
# Existing Date: 2020-03-24
# Existing Date: 2020-03-25
# Existing Date: 2020-03-26
# Existing Date: 2020-03-27
# Existing Date: 2020-03-28
# Existing Date: 2020-03-29
# Existing Date: 2020-03-30
# Existing Date: 2020-03-31
# Existing Date: 2020-04-01
# Existing Date: 2020-04-02
# Existing Date: 2020-04-03
# Existing Date: 2020-04-04
# Existing Date: 2020-04-05
# Existing Date: 2020-04-06
# Existing Date: 2020-04-07
# Existing Date: 2020-04-08
# Existing Date: 2020-04-09
# Existing Date: 2020-04-10
# Existing Date: 2020-04-11
# Existing Date: 2020-04-12
# Existing Date: 2020-04-13
# Existing Date: 2020-04-14
# Existing Date: 2020-04-15
# Existing Date: 2020-04-16
# Existing Date: 2020-04-17
# Existing Date: 2020-04-18
# Existing Date: 2020-04-19
# Existing Date: 2020-04-20
# Existing Date: 2020-04-21
# Existing Date: 2020-04-22
# Existing Date: 2020-04-23
# Existing Date: 2020-04-24
# Existing Date: 2020-04-25
# Existing Date: 2020-04-26
# Existing Date: 2020-04-27
# Existing Date: 2020-04-28
# Existing Date: 2020-04-29
# Existing Date: 2020-04-30
# Existing Date: 2020-05-01
# Existing Date: 2020-05-02
# Existing Date: 2020-05-03
# Existing Date: 2020-05-04
# Existing Date: 2020-05-05
# Existing Date: 2020-05-06
# Existing Date: 2020-05-07
# Existing Date: 2020-05-08
# Existing Date: 2020-05-09
# Existing Date: 2020-05-10
# Existing Date: 2020-05-11
# Existing Date: 2020-05-12
# Existing Date: 2020-05-13
# Existing Date: 2020-05-14
# Existing Date: 2020-05-15
# Existing Date: 2020-05-16
# Existing Date: 2020-05-17
# Existing Date: 2020-05-18
# Existing Date: 2020-05-19
# Existing Date: 2020-05-20
# Existing Date: 2020-05-21
# Existing Date: 2020-05-22
# Existing Date: 2020-05-23
# Existing Date: 2020-05-24
# Existing Date: 2020-05-25
# Existing Date: 2020-05-26
# Existing Date: 2020-05-27
# Existing Date: 2020-05-28
# Existing Date: 2020-05-29
# Existing Date: 2020-05-30
# Existing Date: 2020-05-31
# Existing Date: 2020-06-01
# Existing Date: 2020-06-02
# Existing Date: 2020-06-03
# Existing Date: 2020-06-04
# Existing Date: 2020-06-05
# Existing Date: 2020-06-06
# Existing Date: 2020-06-07
# Existing Date: 2020-06-08
# Existing Date: 2020-06-09
# Existing Date: 2020-06-10
# Existing Date: 2020-06-11
# Existing Date: 2020-06-12
# Existing Date: 2020-06-13
# Existing Date: 2020-06-14
# Existing Date: 2020-06-15
# Existing Date: 2020-06-16
# Existing Date: 2020-06-17
# Existing Date: 2020-06-18
# Existing Date: 2020-06-19
# Existing Date: 2020-06-20
# Existing Date: 2020-06-21
# Existing Date: 2020-06-22
# Existing Date: 2020-06-23
# Existing Date: 2020-06-24
# Existing Date: 2020-06-25
# Existing Date: 2020-06-26
# Existing Date: 2020-06-27
# Existing Date: 2020-06-28
# Existing Date: 2020-06-29
# Existing Date: 2020-06-30
# Existing Date: 2020-07-01
# Existing Date: 2020-07-02
# Existing Date: 2020-07-03
# Existing Date: 2020-07-04
# Existing Date: 2020-07-05
# Existing Date: 2020-07-06
# Existing Date: 2020-07-07
# Existing Date: 2020-07-08
# Existing Date: 2020-07-09
# Existing Date: 2020-07-10
# Existing Date: 2020-07-11
# Existing Date: 2020-07-12
# Existing Date: 2020-07-13
# Existing Date: 2020-07-14
# Existing Date: 2020-07-15
# Existing Date: 2020-07-16
# Existing Date: 2020-07-17
# Existing Date: 2020-07-18
# Existing Date: 2020-07-19
# Existing Date: 2020-07-20
# Existing Date: 2020-07-21
# Existing Date: 2020-07-22
# Existing Date: 2020-07-23
# Existing Date: 2020-07-24
# Existing Date: 2020-07-25
# Existing Date: 2020-07-26
# Existing Date: 2020-07-27
# Existing Date: 2020-07-28
# Existing Date: 2020-07-29
# Existing Date: 2020-07-30
# Existing Date: 2020-07-31
# Existing Date: 2020-08-01
# Existing Date: 2020-08-02
# Existing Date: 2020-08-03
# Existing Date: 2020-08-04
# Existing Date: 2020-08-05
# Existing Date: 2020-08-06
# Existing Date: 2020-08-07
# Existing Date: 2020-08-08
# Existing Date: 2020-08-09
# Existing Date: 2020-08-10
# Existing Date: 2020-08-11
# Existing Date: 2020-08-12
# Existing Date: 2020-08-13
# Existing Date: 2020-08-14
# Existing Date: 2020-08-15
# Existing Date: 2020-08-16
# Existing Date: 2020-08-17
# Existing Date: 2020-08-18
# Existing Date: 2020-08-19
# Existing Date: 2020-08-20
# Existing Date: 2020-08-21
# Existing Date: 2020-08-22
# Existing Date: 2020-08-23
# Existing Date: 2020-08-24
# Existing Date: 2020-08-25
# Existing Date: 2020-08-26
# Existing Date: 2020-08-27
# Existing Date: 2020-08-28
# Existing Date: 2020-08-29
# Existing Date: 2020-08-30
# Existing Date: 2020-08-31
# Existing Date: 2020-09-01
# Existing Date: 2020-09-02
# Existing Date: 2020-09-03
# Existing Date: 2020-09-04
# Existing Date: 2020-09-05
# Existing Date: 2020-09-06
# Existing Date: 2020-09-07
# Existing Date: 2020-09-08
# Existing Date: 2020-09-09
# Existing Date: 2020-09-10
# Existing Date: 2020-09-11
# Existing Date: 2020-09-12
# Existing Date: 2020-09-13
# Existing Date: 2020-09-14
# Existing Date: 2020-09-15
# Existing Date: 2020-09-16
# Existing Date: 2020-09-17
# Existing Date: 2020-09-18
# Existing Date: 2020-09-19
# Existing Date: 2020-09-20
# Existing Date: 2020-09-21
# Existing Date: 2020-09-22
# Existing Date: 2020-09-23
# Existing Date: 2020-09-24
# Existing Date: 2020-09-25
# Existing Date: 2020-09-26
# Existing Date: 2020-09-27
# Existing Date: 2020-09-28
# Existing Date: 2020-09-29
# Existing Date: 2020-09-30
# Existing Date: 2020-10-01
# Existing Date: 2020-10-02
# Existing Date: 2020-10-03
# Existing Date: 2020-10-04
# Existing Date: 2020-10-05
# Existing Date: 2020-10-06
# Existing Date: 2020-10-07
# Existing Date: 2020-10-08
# Existing Date: 2020-10-09
# Existing Date: 2020-10-10
# Existing Date: 2020-10-11
# Existing Date: 2020-10-12
# Existing Date: 2020-10-13
# Existing Date: 2020-10-14
# Existing Date: 2020-10-15
# Existing Date: 2020-10-16
# Existing Date: 2020-10-17
# Existing Date: 2020-10-18
# Existing Date: 2020-10-19
# Existing Date: 2020-10-20
# Existing Date: 2020-10-21
# Existing Date: 2020-10-22
# Existing Date: 2020-10-23
# Existing Date: 2020-10-24
# Existing Date: 2020-10-25
# Existing Date: 2020-10-26
# Existing Date: 2020-10-27
# Existing Date: 2020-10-28
# Existing Date: 2020-10-29
# Existing Date: 2020-10-30
# Existing Date: 2020-10-31
# Existing Date: 2020-11-01
# Existing Date: 2020-11-02
# Existing Date: 2020-11-03
# Existing Date: 2020-11-04
# Existing Date: 2020-11-05
# Existing Date: 2020-11-06
# Existing Date: 2020-11-07
# Existing Date: 2020-11-08
# Existing Date: 2020-11-09
# Existing Date: 2020-11-10
# Existing Date: 2020-11-11
# Existing Date: 2020-11-12
# Existing Date: 2020-11-13
# Existing Date: 2020-11-14
# Existing Date: 2020-11-15
# Existing Date: 2020-11-16
# Existing Date: 2020-11-17
# Existing Date: 2020-11-18
# Existing Date: 2020-11-19
# Existing Date: 2020-11-20
# Existing Date: 2020-11-21
# Existing Date: 2020-11-22
# Existing Date: 2020-11-23
# Existing Date: 2020-11-24
# Existing Date: 2020-11-25
# Existing Date: 2020-11-26
# Existing Date: 2020-11-27
# Existing Date: 2020-11-28
# Existing Date: 2020-11-29
# Existing Date: 2020-11-30
# Existing Date: 2020-12-01
# Existing Date: 2020-12-02
# Existing Date: 2020-12-03
# Existing Date: 2020-12-04
# Existing Date: 2020-12-05
# Existing Date: 2020-12-06
# Existing Date: 2020-12-07
# Existing Date: 2020-12-08
# Existing Date: 2020-12-09
# Existing Date: 2020-12-10
# Existing Date: 2020-12-11
# Existing Date: 2020-12-12
# Existing Date: 2020-12-13
# Existing Date: 2020-12-14
# Existing Date: 2020-12-15
# Existing Date: 2020-12-16
# Existing Date: 2020-12-17
# Existing Date: 2020-12-18
# Existing Date: 2020-12-19
# Existing Date: 2020-12-20
# Existing Date: 2020-12-21
# Existing Date: 2020-12-22
# Existing Date: 2020-12-23
# Existing Date: 2020-12-24
# Existing Date: 2020-12-25
# Existing Date: 2020-12-26
# Existing Date: 2020-12-27
# Existing Date: 2020-12-28
# Existing Date: 2020-12-29
# Existing Date: 2020-12-30
# Existing Date: 2020-12-31
# Existing Date: 2021-01-01
# Existing Date: 2021-01-02
# Existing Date: 2021-01-03
# Existing Date: 2021-01-04
# Existing Date: 2021-01-05
# Existing Date: 2021-01-06
# Existing Date: 2021-01-07
# Existing Date: 2021-01-08
# Existing Date: 2021-01-09
# Existing Date: 2021-01-10
# Existing Date: 2021-01-11
# Existing Date: 2021-01-12
# Existing Date: 2021-01-13
# Existing Date: 2021-01-14
# Existing Date: 2021-01-15
# Existing Date: 2021-01-16
# Existing Date: 2021-01-17
# Existing Date: 2021-01-18
# Existing Date: 2021-01-19
# Existing Date: 2021-01-20
# Existing Date: 2021-01-21
# Existing Date: 2021-01-22
# Existing Date: 2021-01-23
# Existing Date: 2021-01-24
# Existing Date: 2021-01-25
# Existing Date: 2021-01-26
# Existing Date: 2021-01-27
# Existing Date: 2021-01-28
# Existing Date: 2021-01-29
# Existing Date: 2021-01-30
# Existing Date: 2021-01-31
# Existing Date: 2021-02-01
# Existing Date: 2021-02-02
# Existing Date: 2021-02-03
# Existing Date: 2021-02-04
# Existing Date: 2021-02-05
# Existing Date: 2021-02-06
# Existing Date: 2021-02-07
# Existing Date: 2021-02-08
# Existing Date: 2021-02-09
# Existing Date: 2021-02-10
# Existing Date: 2021-02-11
# Existing Date: 2021-02-12
# Existing Date: 2021-02-13
# Existing Date: 2021-02-14
# Existing Date: 2021-02-15
# Existing Date: 2021-02-16
# Existing Date: 2021-02-17
# Existing Date: 2021-02-18
# Existing Date: 2021-02-19
# Existing Date: 2021-02-20
# Existing Date: 2021-02-21
# Existing Date: 2021-02-22
# Existing Date: 2021-02-23
# Existing Date: 2021-02-24
# Existing Date: 2021-02-25
# Existing Date: 2021-02-26
# Existing Date: 2021-02-27
# Existing Date: 2021-02-28
# Existing Date: 2021-03-01
# Existing Date: 2021-03-02
# Existing Date: 2021-03-03
# Existing Date: 2021-03-04
# Existing Date: 2021-03-05
# Existing Date: 2021-03-06
# Existing Date: 2021-03-07
# Existing Date: 2021-03-08
# Existing Date: 2021-03-09
# Existing Date: 2021-03-10
# Existing Date: 2021-03-11
# Existing Date: 2021-03-12
# Existing Date: 2021-03-13
# Existing Date: 2021-03-14
# Existing Date: 2021-03-15
# Existing Date: 2021-03-16
# Existing Date: 2021-03-17
# Existing Date: 2021-03-18
# Start date at beginning: 2021-03-19
# writing file: C:/Users/there/Anaconda3/WhoAreYouMadeOf/granular_data/web/_2021-03-19.csv
# writing to csv
# Numrows at the start of loop: 0
# Numrows at the end of loop: 7850
# Start date at end: 2021-03-20
# Start date at beginning: 2021-03-20
# writing file: C:/Users/there/Anaconda3/WhoAreYouMadeOf/granular_data/web/_2021-03-20.csv
# writing to csv
# Numrows at the start of loop: 0
# Numrows at the end of loop: 8057
# Start date at end: 2021-03-21
# Existing Date: 2019-11-25
# Existing Date: 2019-11-26
# Existing Date: 2019-11-27
# Existing Date: 2019-11-28
# Existing Date: 2019-11-29
# Existing Date: 2019-11-30
# Existing Date: 2019-12-01
# Existing Date: 2019-12-02
# Existing Date: 2019-12-03
# Existing Date: 2019-12-04
# Existing Date: 2019-12-05
# Existing Date: 2019-12-06
# Existing Date: 2019-12-07
# Existing Date: 2019-12-08
# Existing Date: 2019-12-09
# Existing Date: 2019-12-10
# Existing Date: 2019-12-11
# Existing Date: 2019-12-12
# Existing Date: 2019-12-13
# Existing Date: 2019-12-14
# Existing Date: 2019-12-15
# Existing Date: 2019-12-16
# Existing Date: 2019-12-17
# Existing Date: 2019-12-18
# Existing Date: 2019-12-19
# Existing Date: 2019-12-20
# Existing Date: 2019-12-21
# Existing Date: 2019-12-22
# Existing Date: 2019-12-23
# Existing Date: 2019-12-24
# Existing Date: 2019-12-25
# Existing Date: 2019-12-26
# Existing Date: 2019-12-27
# Existing Date: 2019-12-28
# Existing Date: 2019-12-29
# Existing Date: 2019-12-30
# Existing Date: 2019-12-31
# Existing Date: 2020-01-01
# Existing Date: 2020-01-02
# Existing Date: 2020-01-03
# Existing Date: 2020-01-04
# Existing Date: 2020-01-05
# Existing Date: 2020-01-06
# Existing Date: 2020-01-07
# Existing Date: 2020-01-08
# Existing Date: 2020-01-09
# Existing Date: 2020-01-10
# Existing Date: 2020-01-11
# Existing Date: 2020-01-12
# Existing Date: 2020-01-13
# Existing Date: 2020-01-14
# Existing Date: 2020-01-15
# Existing Date: 2020-01-16
# Existing Date: 2020-01-17
# Existing Date: 2020-01-18
# Existing Date: 2020-01-19
# Existing Date: 2020-01-20
# Existing Date: 2020-01-21
# Existing Date: 2020-01-22
# Existing Date: 2020-01-23
# Existing Date: 2020-01-24
# Existing Date: 2020-01-25
# Existing Date: 2020-01-26
# Existing Date: 2020-01-27
# Existing Date: 2020-01-28
# Existing Date: 2020-01-29
# Existing Date: 2020-01-30
# Existing Date: 2020-01-31
# Existing Date: 2020-02-01
# Existing Date: 2020-02-02
# Existing Date: 2020-02-03
# Existing Date: 2020-02-04
# Existing Date: 2020-02-05
# Existing Date: 2020-02-06
# Existing Date: 2020-02-07
# Existing Date: 2020-02-08
# Existing Date: 2020-02-09
# Existing Date: 2020-02-10
# Existing Date: 2020-02-11
# Existing Date: 2020-02-12
# Existing Date: 2020-02-13
# Existing Date: 2020-02-14
# Existing Date: 2020-02-15
# Existing Date: 2020-02-16
# Existing Date: 2020-02-17
# Existing Date: 2020-02-18
# Existing Date: 2020-02-19
# Existing Date: 2020-02-20
# Existing Date: 2020-02-21
# Existing Date: 2020-02-22
# Existing Date: 2020-02-23
# Existing Date: 2020-02-24
# Existing Date: 2020-02-25
# Existing Date: 2020-02-26
# Existing Date: 2020-02-27
# Existing Date: 2020-02-28
# Existing Date: 2020-02-29
# Existing Date: 2020-03-01
# Existing Date: 2020-03-02
# Existing Date: 2020-03-03
# Existing Date: 2020-03-04
# Existing Date: 2020-03-05
# Existing Date: 2020-03-06
# Existing Date: 2020-03-07
# Existing Date: 2020-03-08
# Existing Date: 2020-03-09
# Existing Date: 2020-03-10
# Existing Date: 2020-03-11
# Existing Date: 2020-03-12
# Existing Date: 2020-03-13
# Existing Date: 2020-03-14
# Existing Date: 2020-03-15
# Existing Date: 2020-03-16
# Existing Date: 2020-03-17
# Existing Date: 2020-03-18
# Existing Date: 2020-03-19
# Existing Date: 2020-03-20
# Existing Date: 2020-03-21
# Existing Date: 2020-03-22
# Existing Date: 2020-03-23
# Existing Date: 2020-03-24
# Existing Date: 2020-03-25
# Existing Date: 2020-03-26
# Existing Date: 2020-03-27
# Existing Date: 2020-03-28
# Existing Date: 2020-03-29
# Existing Date: 2020-03-30
# Existing Date: 2020-03-31
# Existing Date: 2020-04-01
# Existing Date: 2020-04-02
# Existing Date: 2020-04-03
# Existing Date: 2020-04-04
# Existing Date: 2020-04-05
# Existing Date: 2020-04-06
# Existing Date: 2020-04-07
# Existing Date: 2020-04-08
# Existing Date: 2020-04-09
# Existing Date: 2020-04-10
# Existing Date: 2020-04-11
# Existing Date: 2020-04-12
# Existing Date: 2020-04-13
# Existing Date: 2020-04-14
# Existing Date: 2020-04-15
# Existing Date: 2020-04-16
# Existing Date: 2020-04-17
# Existing Date: 2020-04-18
# Existing Date: 2020-04-19
# Existing Date: 2020-04-20
# Existing Date: 2020-04-21
# Existing Date: 2020-04-22
# Existing Date: 2020-04-23
# Existing Date: 2020-04-24
# Existing Date: 2020-04-25
# Existing Date: 2020-04-26
# Existing Date: 2020-04-27
# Existing Date: 2020-04-28
# Existing Date: 2020-04-29
# Existing Date: 2020-04-30
# Existing Date: 2020-05-01
# Existing Date: 2020-05-02
# Existing Date: 2020-05-03
# Existing Date: 2020-05-04
# Existing Date: 2020-05-05
# Existing Date: 2020-05-06
# Existing Date: 2020-05-07
# Existing Date: 2020-05-08
# Existing Date: 2020-05-09
# Existing Date: 2020-05-10
# Existing Date: 2020-05-11
# Existing Date: 2020-05-12
# Existing Date: 2020-05-13
# Existing Date: 2020-05-14
# Existing Date: 2020-05-15
# Existing Date: 2020-05-16
# Existing Date: 2020-05-17
# Existing Date: 2020-05-18
# Existing Date: 2020-05-19
# Existing Date: 2020-05-20
# Existing Date: 2020-05-21
# Existing Date: 2020-05-22
# Existing Date: 2020-05-23
# Existing Date: 2020-05-24
# Existing Date: 2020-05-25
# Existing Date: 2020-05-26
# Existing Date: 2020-05-27
# Existing Date: 2020-05-28
# Existing Date: 2020-05-29
# Existing Date: 2020-05-30
# Existing Date: 2020-05-31
# Existing Date: 2020-06-01
# Existing Date: 2020-06-02
# Existing Date: 2020-06-03
# Existing Date: 2020-06-04
# Existing Date: 2020-06-05
# Existing Date: 2020-06-06
# Existing Date: 2020-06-07
# Existing Date: 2020-06-08
# Existing Date: 2020-06-09
# Existing Date: 2020-06-10
# Existing Date: 2020-06-11
# Existing Date: 2020-06-12
# Existing Date: 2020-06-13
# Existing Date: 2020-06-14
# Existing Date: 2020-06-15
# Existing Date: 2020-06-16
# Existing Date: 2020-06-17
# Existing Date: 2020-06-18
# Existing Date: 2020-06-19
# Existing Date: 2020-06-20
# Existing Date: 2020-06-21
# Existing Date: 2020-06-22
# Existing Date: 2020-06-23
# Existing Date: 2020-06-24
# Existing Date: 2020-06-25
# Existing Date: 2020-06-26
# Existing Date: 2020-06-27
# Existing Date: 2020-06-28
# Existing Date: 2020-06-29
# Existing Date: 2020-06-30
# Existing Date: 2020-07-01
# Existing Date: 2020-07-02
# Existing Date: 2020-07-03
# Existing Date: 2020-07-04
# Existing Date: 2020-07-05
# Existing Date: 2020-07-06
# Existing Date: 2020-07-07
# Existing Date: 2020-07-08
# Existing Date: 2020-07-09
# Existing Date: 2020-07-10
# Existing Date: 2020-07-11
# Existing Date: 2020-07-12
# Existing Date: 2020-07-13
# Existing Date: 2020-07-14
# Existing Date: 2020-07-15
# Existing Date: 2020-07-16
# Existing Date: 2020-07-17
# Existing Date: 2020-07-18
# Existing Date: 2020-07-19
# Existing Date: 2020-07-20
# Existing Date: 2020-07-21
# Existing Date: 2020-07-22
# Existing Date: 2020-07-23
# Existing Date: 2020-07-24
# Existing Date: 2020-07-25
# Existing Date: 2020-07-26
# Existing Date: 2020-07-27
# Existing Date: 2020-07-28
# Existing Date: 2020-07-29
# Existing Date: 2020-07-30
# Existing Date: 2020-07-31
# Existing Date: 2020-08-01
# Existing Date: 2020-08-02
# Existing Date: 2020-08-03
# Existing Date: 2020-08-04
# Existing Date: 2020-08-05
# Existing Date: 2020-08-06
# Existing Date: 2020-08-07
# Existing Date: 2020-08-08
# Existing Date: 2020-08-09
# Existing Date: 2020-08-10
# Existing Date: 2020-08-11
# Existing Date: 2020-08-12
# Existing Date: 2020-08-13
# Existing Date: 2020-08-14
# Existing Date: 2020-08-15
# Existing Date: 2020-08-16
# Existing Date: 2020-08-17
# Existing Date: 2020-08-18
# Existing Date: 2020-08-19
# Existing Date: 2020-08-20
# Existing Date: 2020-08-21
# Existing Date: 2020-08-22
# Existing Date: 2020-08-23
# Existing Date: 2020-08-24
# Existing Date: 2020-08-25
# Existing Date: 2020-08-26
# Existing Date: 2020-08-27
# Existing Date: 2020-08-28
# Existing Date: 2020-08-29
# Existing Date: 2020-08-30
# Existing Date: 2020-08-31
# Existing Date: 2020-09-01
# Existing Date: 2020-09-02
# Existing Date: 2020-09-03
# Existing Date: 2020-09-04
# Existing Date: 2020-09-05
# Existing Date: 2020-09-06
# Existing Date: 2020-09-07
# Existing Date: 2020-09-08
# Existing Date: 2020-09-09
# Existing Date: 2020-09-10
# Existing Date: 2020-09-11
# Existing Date: 2020-09-12
# Existing Date: 2020-09-13
# Existing Date: 2020-09-14
# Existing Date: 2020-09-15
# Existing Date: 2020-09-16
# Existing Date: 2020-09-17
# Existing Date: 2020-09-18
# Existing Date: 2020-09-19
# Existing Date: 2020-09-20
# Existing Date: 2020-09-21
# Existing Date: 2020-09-22
# Existing Date: 2020-09-23
# Existing Date: 2020-09-24
# Existing Date: 2020-09-25
# Existing Date: 2020-09-26
# Existing Date: 2020-09-27
# Existing Date: 2020-09-28
# Existing Date: 2020-09-29
# Existing Date: 2020-09-30
# Existing Date: 2020-10-01
# Existing Date: 2020-10-02
# Existing Date: 2020-10-03
# Existing Date: 2020-10-04
# Existing Date: 2020-10-05
# Existing Date: 2020-10-06
# Existing Date: 2020-10-07
# Existing Date: 2020-10-08
# Existing Date: 2020-10-09
# Existing Date: 2020-10-10
# Existing Date: 2020-10-11
# Existing Date: 2020-10-12
# Existing Date: 2020-10-13
# Existing Date: 2020-10-14
# Existing Date: 2020-10-15
# Existing Date: 2020-10-16
# Existing Date: 2020-10-17
# Existing Date: 2020-10-18
# Existing Date: 2020-10-19
# Existing Date: 2020-10-20
# Existing Date: 2020-10-21
# Existing Date: 2020-10-22
# Existing Date: 2020-10-23
# Existing Date: 2020-10-24
# Existing Date: 2020-10-25
# Existing Date: 2020-10-26
# Existing Date: 2020-10-27
# Existing Date: 2020-10-28
# Existing Date: 2020-10-29
# Existing Date: 2020-10-30
# Existing Date: 2020-10-31
# Existing Date: 2020-11-01
# Existing Date: 2020-11-02
# Existing Date: 2020-11-03
# Existing Date: 2020-11-04
# Existing Date: 2020-11-05
# Existing Date: 2020-11-06
# Existing Date: 2020-11-07
# Existing Date: 2020-11-08
# Existing Date: 2020-11-09
# Existing Date: 2020-11-10
# Existing Date: 2020-11-11
# Existing Date: 2020-11-12
# Existing Date: 2020-11-13
# Existing Date: 2020-11-14
# Existing Date: 2020-11-15
# Existing Date: 2020-11-16
# Existing Date: 2020-11-17
# Existing Date: 2020-11-18
# Existing Date: 2020-11-19
# Existing Date: 2020-11-20
# Existing Date: 2020-11-21
# Existing Date: 2020-11-22
# Existing Date: 2020-11-23
# Existing Date: 2020-11-24
# Existing Date: 2020-11-25
# Existing Date: 2020-11-26
# Existing Date: 2020-11-27
# Existing Date: 2020-11-28
# Existing Date: 2020-11-29
# Existing Date: 2020-11-30
# Existing Date: 2020-12-01
# Existing Date: 2020-12-02
# Existing Date: 2020-12-03
# Existing Date: 2020-12-04
# Existing Date: 2020-12-05
# Existing Date: 2020-12-06
# Existing Date: 2020-12-07
# Existing Date: 2020-12-08
# Existing Date: 2020-12-09
# Existing Date: 2020-12-10
# Existing Date: 2020-12-11
# Existing Date: 2020-12-12
# Existing Date: 2020-12-13
# Existing Date: 2020-12-14
# Existing Date: 2020-12-15
# Existing Date: 2020-12-16
# Existing Date: 2020-12-17
# Existing Date: 2020-12-18
# Existing Date: 2020-12-19
# Existing Date: 2020-12-20
# Existing Date: 2020-12-21
# Existing Date: 2020-12-22
# Existing Date: 2020-12-23
# Existing Date: 2020-12-24
# Existing Date: 2020-12-25
# Existing Date: 2020-12-26
# Existing Date: 2020-12-27
# Existing Date: 2020-12-28
# Existing Date: 2020-12-29
# Existing Date: 2020-12-30
# Existing Date: 2020-12-31
# Existing Date: 2021-01-01
# Existing Date: 2021-01-02
# Existing Date: 2021-01-03
# Existing Date: 2021-01-04
# Existing Date: 2021-01-05
# Existing Date: 2021-01-06
# Existing Date: 2021-01-07
# Existing Date: 2021-01-08
# Existing Date: 2021-01-09
# Existing Date: 2021-01-10
# Existing Date: 2021-01-11
# Existing Date: 2021-01-12
# Existing Date: 2021-01-13
# Existing Date: 2021-01-14
# Existing Date: 2021-01-15
# Existing Date: 2021-01-16
# Existing Date: 2021-01-17
# Existing Date: 2021-01-18
# Existing Date: 2021-01-19
# Existing Date: 2021-01-20
# Existing Date: 2021-01-21
# Existing Date: 2021-01-22
# Existing Date: 2021-01-23
# Existing Date: 2021-01-24
# Existing Date: 2021-01-25
# Existing Date: 2021-01-26
# Existing Date: 2021-01-27
# Existing Date: 2021-01-28
# Existing Date: 2021-01-29
# Existing Date: 2021-01-30
# Existing Date: 2021-01-31
# Existing Date: 2021-02-01
# Existing Date: 2021-02-02
# Existing Date: 2021-02-03
# Existing Date: 2021-02-04
# Existing Date: 2021-02-05
# Existing Date: 2021-02-06
# Existing Date: 2021-02-07
# Existing Date: 2021-02-08
# Existing Date: 2021-02-09
# Existing Date: 2021-02-10
# Existing Date: 2021-02-11
# Existing Date: 2021-02-12
# Existing Date: 2021-02-13
# Existing Date: 2021-02-14
# Existing Date: 2021-02-15
# Existing Date: 2021-02-16
# Existing Date: 2021-02-17
# Existing Date: 2021-02-18
# Existing Date: 2021-02-19
# Existing Date: 2021-02-20
# Existing Date: 2021-02-21
# Existing Date: 2021-02-22
# Existing Date: 2021-02-23
# Existing Date: 2021-02-24
# Existing Date: 2021-02-25
# Existing Date: 2021-02-26
# Existing Date: 2021-02-27
# Existing Date: 2021-02-28
# Existing Date: 2021-03-01
# Existing Date: 2021-03-02
# Existing Date: 2021-03-03
# Existing Date: 2021-03-04
# Existing Date: 2021-03-05
# Existing Date: 2021-03-06
# Existing Date: 2021-03-07
# Existing Date: 2021-03-08
# Existing Date: 2021-03-09
# Existing Date: 2021-03-10
# Existing Date: 2021-03-11
# Existing Date: 2021-03-12
# Existing Date: 2021-03-13
# Existing Date: 2021-03-14
# Existing Date: 2021-03-15
# Existing Date: 2021-03-16
# Existing Date: 2021-03-17
# Existing Date: 2021-03-18
# Existing Date: 2021-03-19
# Start date at beginning: 2021-03-20
# writing file: C:/Users/there/Anaconda3/WhoAreYouMadeOf/granular_data/image/_2021-03-20.csv
# writing to csv
# Numrows at the start of loop: 0
# Numrows at the end of loop: 3842
# Start date at end: 2021-03-21
# Existing Date: 2019-11-25
# Existing Date: 2019-11-26
# Existing Date: 2019-11-27
# Existing Date: 2019-11-28
# Existing Date: 2019-11-29
# Existing Date: 2019-11-30
# Existing Date: 2019-12-01
# Existing Date: 2019-12-02
# Existing Date: 2019-12-03
# Existing Date: 2019-12-04
# Existing Date: 2019-12-05
# Existing Date: 2019-12-06
# Existing Date: 2019-12-07
# Existing Date: 2019-12-08
# Existing Date: 2019-12-09
# Existing Date: 2019-12-10
# Existing Date: 2019-12-11
# Existing Date: 2019-12-12
# Existing Date: 2019-12-13
# Existing Date: 2019-12-14
# Existing Date: 2019-12-15
# Existing Date: 2019-12-16
# Existing Date: 2019-12-17
# Existing Date: 2019-12-18
# Existing Date: 2019-12-19
# Existing Date: 2019-12-20
# Existing Date: 2019-12-21
# Existing Date: 2019-12-22
# Existing Date: 2019-12-23
# Existing Date: 2019-12-24
# Existing Date: 2019-12-25
# Existing Date: 2019-12-26
# Existing Date: 2019-12-27
# Existing Date: 2019-12-28
# Existing Date: 2019-12-29
# Existing Date: 2019-12-30
# Existing Date: 2019-12-31
# Existing Date: 2020-01-01
# Existing Date: 2020-01-02
# Existing Date: 2020-01-03
# Existing Date: 2020-01-04
# Existing Date: 2020-01-05
# Existing Date: 2020-01-06
# Existing Date: 2020-01-07
# Existing Date: 2020-01-08
# Existing Date: 2020-01-09
# Existing Date: 2020-01-10
# Existing Date: 2020-01-11
# Existing Date: 2020-01-12
# Existing Date: 2020-01-13
# Existing Date: 2020-01-14
# Existing Date: 2020-01-15
# Existing Date: 2020-01-16
# Existing Date: 2020-01-17
# Existing Date: 2020-01-18
# Existing Date: 2020-01-19
# Existing Date: 2020-01-20
# Existing Date: 2020-01-21
# Existing Date: 2020-01-22
# Existing Date: 2020-01-23
# Existing Date: 2020-01-24
# Existing Date: 2020-01-25
# Existing Date: 2020-01-26
# Existing Date: 2020-01-27
# Existing Date: 2020-01-28
# Existing Date: 2020-01-29
# Existing Date: 2020-01-30
# Existing Date: 2020-01-31
# Existing Date: 2020-02-01
# Existing Date: 2020-02-02
# Existing Date: 2020-02-03
# Existing Date: 2020-02-04
# Existing Date: 2020-02-05
# Existing Date: 2020-02-06
# Existing Date: 2020-02-07
# Existing Date: 2020-02-08
# Existing Date: 2020-02-09
# Existing Date: 2020-02-10
# Existing Date: 2020-02-11
# Existing Date: 2020-02-12
# Existing Date: 2020-02-13
# Existing Date: 2020-02-14
# Existing Date: 2020-02-15
# Existing Date: 2020-02-16
# Existing Date: 2020-02-17
# Existing Date: 2020-02-18
# Existing Date: 2020-02-19
# Existing Date: 2020-02-20
# Existing Date: 2020-02-21
# Existing Date: 2020-02-22
# Existing Date: 2020-02-23
# Existing Date: 2020-02-24
# Existing Date: 2020-02-25
# Existing Date: 2020-02-26
# Existing Date: 2020-02-27
# Existing Date: 2020-02-28
# Existing Date: 2020-02-29
# Existing Date: 2020-03-01
# Existing Date: 2020-03-02
# Existing Date: 2020-03-03
# Existing Date: 2020-03-04
# Existing Date: 2020-03-05
# Existing Date: 2020-03-06
# Existing Date: 2020-03-07
# Existing Date: 2020-03-08
# Existing Date: 2020-03-09
# Existing Date: 2020-03-10
# Existing Date: 2020-03-11
# Existing Date: 2020-03-12
# Existing Date: 2020-03-13
# Existing Date: 2020-03-14
# Existing Date: 2020-03-15
# Existing Date: 2020-03-16
# Existing Date: 2020-03-17
# Existing Date: 2020-03-18
# Existing Date: 2020-03-19
# Existing Date: 2020-03-20
# Existing Date: 2020-03-21
# Existing Date: 2020-03-22
# Existing Date: 2020-03-23
# Existing Date: 2020-03-24
# Existing Date: 2020-03-25
# Existing Date: 2020-03-26
# Existing Date: 2020-03-27
# Existing Date: 2020-03-28
# Existing Date: 2020-03-29
# Existing Date: 2020-03-30
# Existing Date: 2020-03-31
# Existing Date: 2020-04-01
# Existing Date: 2020-04-02
# Existing Date: 2020-04-03
# Existing Date: 2020-04-04
# Existing Date: 2020-04-05
# Existing Date: 2020-04-06
# Existing Date: 2020-04-07
# Existing Date: 2020-04-08
# Existing Date: 2020-04-09
# Existing Date: 2020-04-10
# Existing Date: 2020-04-11
# Existing Date: 2020-04-12
# Existing Date: 2020-04-13
# Existing Date: 2020-04-14
# Existing Date: 2020-04-15
# Existing Date: 2020-04-16
# Existing Date: 2020-04-17
# Existing Date: 2020-04-18
# Existing Date: 2020-04-19
# Existing Date: 2020-04-20
# Existing Date: 2020-04-21
# Existing Date: 2020-04-22
# Existing Date: 2020-04-23
# Existing Date: 2020-04-24
# Existing Date: 2020-04-25
# Existing Date: 2020-04-26
# Existing Date: 2020-04-27
# Existing Date: 2020-04-28
# Existing Date: 2020-04-29
# Existing Date: 2020-04-30
# Existing Date: 2020-05-01
# Existing Date: 2020-05-02
# Existing Date: 2020-05-03
# Existing Date: 2020-05-04
# Existing Date: 2020-05-05
# Existing Date: 2020-05-06
# Existing Date: 2020-05-07
# Existing Date: 2020-05-08
# Existing Date: 2020-05-09
# Existing Date: 2020-05-10
# Existing Date: 2020-05-11
# Existing Date: 2020-05-12
# Existing Date: 2020-05-13
# Existing Date: 2020-05-14
# Existing Date: 2020-05-15
# Existing Date: 2020-05-16
# Existing Date: 2020-05-17
# Existing Date: 2020-05-18
# Existing Date: 2020-05-19
# Existing Date: 2020-05-20
# Existing Date: 2020-05-21
# Existing Date: 2020-05-22
# Existing Date: 2020-05-23
# Existing Date: 2020-05-24
# Existing Date: 2020-05-25
# Existing Date: 2020-05-26
# Existing Date: 2020-05-27
# Existing Date: 2020-05-28
# Existing Date: 2020-05-29
# Existing Date: 2020-05-30
# Existing Date: 2020-05-31
# Existing Date: 2020-06-01
# Existing Date: 2020-06-02
# Existing Date: 2020-06-03
# Existing Date: 2020-06-04
# Existing Date: 2020-06-05
# Existing Date: 2020-06-06
# Existing Date: 2020-06-07
# Existing Date: 2020-06-08
# Existing Date: 2020-06-09
# Existing Date: 2020-06-10
# Existing Date: 2020-06-11
# Existing Date: 2020-06-12
# Existing Date: 2020-06-13
# Existing Date: 2020-06-14
# Existing Date: 2020-06-15
# Existing Date: 2020-06-16
# Existing Date: 2020-06-17
# Existing Date: 2020-06-18
# Existing Date: 2020-06-19
# Existing Date: 2020-06-20
# Existing Date: 2020-06-21
# Existing Date: 2020-06-22
# Existing Date: 2020-06-23
# Existing Date: 2020-06-24
# Existing Date: 2020-06-25
# Existing Date: 2020-06-26
# Existing Date: 2020-06-27
# Existing Date: 2020-06-28
# Existing Date: 2020-06-29
# Existing Date: 2020-06-30
# Existing Date: 2020-07-01
# Existing Date: 2020-07-02
# Existing Date: 2020-07-03
# Existing Date: 2020-07-04
# Existing Date: 2020-07-05
# Existing Date: 2020-07-06
# Existing Date: 2020-07-07
# Existing Date: 2020-07-08
# Existing Date: 2020-07-09
# Existing Date: 2020-07-10
# Existing Date: 2020-07-11
# Existing Date: 2020-07-12
# Existing Date: 2020-07-13
# Existing Date: 2020-07-14
# Existing Date: 2020-07-15
# Existing Date: 2020-07-16
# Existing Date: 2020-07-17
# Existing Date: 2020-07-18
# Existing Date: 2020-07-19
# Existing Date: 2020-07-20
# Existing Date: 2020-07-21
# Existing Date: 2020-07-22
# Existing Date: 2020-07-23
# Existing Date: 2020-07-24
# Existing Date: 2020-07-25
# Existing Date: 2020-07-26
# Existing Date: 2020-07-27
# Existing Date: 2020-07-28
# Existing Date: 2020-07-29
# Existing Date: 2020-07-30
# Existing Date: 2020-07-31
# Existing Date: 2020-08-01
# Existing Date: 2020-08-02
# Existing Date: 2020-08-03
# Existing Date: 2020-08-04
# Existing Date: 2020-08-05
# Existing Date: 2020-08-06
# Existing Date: 2020-08-07
# Existing Date: 2020-08-08
# Existing Date: 2020-08-09
# Existing Date: 2020-08-10
# Existing Date: 2020-08-11
# Existing Date: 2020-08-12
# Existing Date: 2020-08-13
# Existing Date: 2020-08-14
# Existing Date: 2020-08-15
# Existing Date: 2020-08-16
# Existing Date: 2020-08-17
# Existing Date: 2020-08-18
# Existing Date: 2020-08-19
# Existing Date: 2020-08-20
# Existing Date: 2020-08-21
# Existing Date: 2020-08-22
# Existing Date: 2020-08-23
# Existing Date: 2020-08-24
# Existing Date: 2020-08-25
# Existing Date: 2020-08-26
# Existing Date: 2020-08-27
# Existing Date: 2020-08-28
# Existing Date: 2020-08-29
# Existing Date: 2020-08-30
# Existing Date: 2020-08-31
# Existing Date: 2020-09-01
# Existing Date: 2020-09-02
# Existing Date: 2020-09-03
# Existing Date: 2020-09-04
# Existing Date: 2020-09-05
# Existing Date: 2020-09-06
# Existing Date: 2020-09-07
# Existing Date: 2020-09-08
# Existing Date: 2020-09-09
# Existing Date: 2020-09-10
# Existing Date: 2020-09-11
# Existing Date: 2020-09-12
# Existing Date: 2020-09-13
# Existing Date: 2020-09-14
# Existing Date: 2020-09-15
# Existing Date: 2020-09-16
# Existing Date: 2020-09-17
# Existing Date: 2020-09-18
# Existing Date: 2020-09-19
# Existing Date: 2020-09-20
# Existing Date: 2020-09-21
# Existing Date: 2020-09-22
# Existing Date: 2020-09-23
# Existing Date: 2020-09-24
# Existing Date: 2020-09-25
# Existing Date: 2020-09-26
# Existing Date: 2020-09-27
# Existing Date: 2020-09-28
# Existing Date: 2020-09-29
# Existing Date: 2020-09-30
# Existing Date: 2020-10-01
# Existing Date: 2020-10-02
# Existing Date: 2020-10-03
# Existing Date: 2020-10-04
# Existing Date: 2020-10-05
# Existing Date: 2020-10-06
# Existing Date: 2020-10-07
# Existing Date: 2020-10-08
# Existing Date: 2020-10-09
# Existing Date: 2020-10-10
# Existing Date: 2020-10-11
# Existing Date: 2020-10-12
# Existing Date: 2020-10-13
# Existing Date: 2020-10-14
# Existing Date: 2020-10-15
# Existing Date: 2020-10-16
# Existing Date: 2020-10-17
# Existing Date: 2020-10-18
# Existing Date: 2020-10-19
# Existing Date: 2020-10-20
# Existing Date: 2020-10-21
# Existing Date: 2020-10-22
# Existing Date: 2020-10-23
# Existing Date: 2020-10-24
# Existing Date: 2020-10-25
# Existing Date: 2020-10-26
# Existing Date: 2020-10-27
# Existing Date: 2020-10-28
# Existing Date: 2020-10-29
# Existing Date: 2020-10-30
# Existing Date: 2020-10-31
# Existing Date: 2020-11-01
# Existing Date: 2020-11-02
# Existing Date: 2020-11-03
# Existing Date: 2020-11-04
# Existing Date: 2020-11-05
# Existing Date: 2020-11-06
# Existing Date: 2020-11-07
# Existing Date: 2020-11-08
# Existing Date: 2020-11-09
# Existing Date: 2020-11-10
# Existing Date: 2020-11-11
# Existing Date: 2020-11-12
# Existing Date: 2020-11-13
# Existing Date: 2020-11-14
# Existing Date: 2020-11-15
# Existing Date: 2020-11-16
# Existing Date: 2020-11-17
# Existing Date: 2020-11-18
# Existing Date: 2020-11-19
# Existing Date: 2020-11-20
# Existing Date: 2020-11-21
# Existing Date: 2020-11-22
# Existing Date: 2020-11-23
# Existing Date: 2020-11-24
# Existing Date: 2020-11-25
# Existing Date: 2020-11-26
# Existing Date: 2020-11-27
# Existing Date: 2020-11-28
# Existing Date: 2020-11-29
# Existing Date: 2020-11-30
# Existing Date: 2020-12-01
# Existing Date: 2020-12-02
# Existing Date: 2020-12-03
# Existing Date: 2020-12-04
# Existing Date: 2020-12-05
# Existing Date: 2020-12-06
# Existing Date: 2020-12-07
# Existing Date: 2020-12-08
# Existing Date: 2020-12-09
# Existing Date: 2020-12-10
# Existing Date: 2020-12-11
# Existing Date: 2020-12-12
# Existing Date: 2020-12-13
# Existing Date: 2020-12-14
# Existing Date: 2020-12-15
# Existing Date: 2020-12-16
# Existing Date: 2020-12-17
# Existing Date: 2020-12-18
# Existing Date: 2020-12-19
# Existing Date: 2020-12-20
# Existing Date: 2020-12-21
# Existing Date: 2020-12-22
# Existing Date: 2020-12-23
# Existing Date: 2020-12-24
# Existing Date: 2020-12-25
# Existing Date: 2020-12-26
# Existing Date: 2020-12-27
# Existing Date: 2020-12-28
# Existing Date: 2020-12-29
# Existing Date: 2020-12-30
# Existing Date: 2020-12-31
# Existing Date: 2021-01-01
# Existing Date: 2021-01-02
# Existing Date: 2021-01-03
# Existing Date: 2021-01-04
# Existing Date: 2021-01-05
# Existing Date: 2021-01-06
# Existing Date: 2021-01-07
# Existing Date: 2021-01-08
# Existing Date: 2021-01-09
# Existing Date: 2021-01-10
# Existing Date: 2021-01-11
# Existing Date: 2021-01-12
# Existing Date: 2021-01-13
# Existing Date: 2021-01-14
# Existing Date: 2021-01-15
# Existing Date: 2021-01-16
# Existing Date: 2021-01-17
# Existing Date: 2021-01-18
# Existing Date: 2021-01-19
# Existing Date: 2021-01-20
# Existing Date: 2021-01-21
# Existing Date: 2021-01-22
# Existing Date: 2021-01-23
# Existing Date: 2021-01-24
# Existing Date: 2021-01-25
# Existing Date: 2021-01-26
# Existing Date: 2021-01-27
# Existing Date: 2021-01-28
# Existing Date: 2021-01-29
# Existing Date: 2021-01-30
# Existing Date: 2021-01-31
# Existing Date: 2021-02-01
# Existing Date: 2021-02-02
# Existing Date: 2021-02-03
# Existing Date: 2021-02-04
# Existing Date: 2021-02-05
# Existing Date: 2021-02-06
# Existing Date: 2021-02-07
# Existing Date: 2021-02-08
# Existing Date: 2021-02-09
# Existing Date: 2021-02-10
# Existing Date: 2021-02-11
# Existing Date: 2021-02-12
# Existing Date: 2021-02-13
# Existing Date: 2021-02-14
# Existing Date: 2021-02-15
# Existing Date: 2021-02-16
# Existing Date: 2021-02-17
# Existing Date: 2021-02-18
# Existing Date: 2021-02-19
# Existing Date: 2021-02-20
# Existing Date: 2021-02-21
# Existing Date: 2021-02-22
# Existing Date: 2021-02-23
# Existing Date: 2021-02-24
# Existing Date: 2021-02-25
# Existing Date: 2021-02-26
# Existing Date: 2021-02-27
# Existing Date: 2021-02-28
# Existing Date: 2021-03-01
# Existing Date: 2021-03-02
# Existing Date: 2021-03-03
# Existing Date: 2021-03-04
# Existing Date: 2021-03-05
# Existing Date: 2021-03-06
# Existing Date: 2021-03-07
# Existing Date: 2021-03-08
# Existing Date: 2021-03-09
# Existing Date: 2021-03-10
# Existing Date: 2021-03-11
# Existing Date: 2021-03-12
# Existing Date: 2021-03-13
# Existing Date: 2021-03-14
# Existing Date: 2021-03-15
# Existing Date: 2021-03-16
# Existing Date: 2021-03-17
# Existing Date: 2021-03-18
# Existing Date: 2021-03-19
# Start date at beginning: 2021-03-20
# writing file: C:/Users/there/Anaconda3/WhoAreYouMadeOf/granular_data/video/_2021-03-20.csv
# writing to csv
# Numrows at the start of loop: 0
# Numrows at the end of loop: 65
# Start date at end: 2021-03-21
